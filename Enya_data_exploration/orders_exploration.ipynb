# %%
import pandas as pd

# %%
url_orders='https://drive.google.com/file/d/1gyoqm_HkCXYxPEAotoHy3AnjQb062db0/view?usp=sharing'# orders_copy.csv
path = 'https://drive.google.com/uc?export=download&id='+url_orders.split("/")[-2]
df_orders = pd.read_csv(path)

# %%
#5 items missing from total_paid column. Delete rows?
#created_date should be changed to datetime dtype.
#order_id should be object--not indicated/guided/done by class notebook, though

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %%
df_orders.shape
# Out:
# (226909, 4)

# %%
df_orders.describe()
# Out:
#             order_id     total_paid
# count  226909.000000  226904.000000
# mean   413296.482480     569.225818
# std     65919.250331    1761.778002
# min    241319.000000       0.000000
# 25%    356263.000000      34.190000
# 50%    413040.000000     112.990000
# 75%    470553.000000     525.980000
# max    527401.000000  214747.530000

# %%
df_orders.head()
# Out:
#    order_id         created_date  total_paid      state
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled
# 1    241423  2017-11-06 13:10:02      136.15  Completed
# 2    242832  2017-12-31 17:40:03       15.76  Completed
# 3    243330  2017-02-16 10:59:38       84.98  Completed
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled

# %%
df_orders.tail()
# Out:
#         order_id         created_date  total_paid            state
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order

# %%
#what tendency does the lines with category "shopping basket" show?
#A very large percentage of all orders (over half--52%) are in this category!
#Percentage of cancelled is small (3.2%). Can ignore from analyses? though...shouldn't we remove its total cost from revenue to get actual revenue?

# %%
df_orders['state'].value_counts()
# Out:
# state
# Shopping Basket    117809
# Completed           46605
# Place Order         40883
# Pending             14379
# Cancelled            7233
# Name: count, dtype: int64

# %%
df_orders['state'].value_counts(normalize=True)
# Out:
# state
# Shopping Basket    0.519191
# Completed          0.205391
# Place Order        0.180174
# Pending            0.063369
# Cancelled          0.031876
# Name: proportion, dtype: float64

# %%
df_orders['state'].hist()
# Out:
# <Axes: >

# %%
#These missing 5 seem to be the same as shown in the info

# %%
df_orders.isnull().sum()
# Out:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64

# %%
df_orders['total_paid'].isna().sum()
# Out:
# 5

# %%
#There are no duplicated rows

# %%
df_orders.duplicated().sum()
# Out:
# 0
