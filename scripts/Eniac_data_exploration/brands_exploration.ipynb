# %%
import pandas as pd

# %%
url_brands='https://drive.google.com/file/d/1C9fPQuinXOYkWe0NzcDgG3vLDg2seV1b/view?usp=sharing' # brands_copy.csv
path = 'https://drive.google.com/uc?export=download&id='+url_brands.split("/")[-2]
df_brands = pd.read_csv(path)

# %%
df_brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %%
df_brands.shape
# Out:
# (187, 2)

# %%
#why are some values in column long not unique when they are in the short column? (mostly curiosity)

# %%
df_brands.describe()
# Out:
#        short    long
# count    187     187
# unique   187     181
# top      8MO  Mophie
# freq       1       2

# %%
df_brands.head()
# Out:
#   short       long
# 0   8MO  8Mobility
# 1   ACM       Acme
# 2   ADN     Adonit
# 3   AII      Aiino
# 4   AKI     Akitio

# %%
df_brands.tail()
# Out:
#     short      long
# 182   XOO    Xoopar
# 183   XRI    X-Rite
# 184   XTO     Xtorm
# 185   ZAG  ZaggKeys
# 186   ZEP      Zepp

# %%
df_brands.isnull().sum()
# Out:
# short    0
# long     0
# dtype: int64

# %%
df_brands.isna().sum()
# Out:
# short    0
# long     0
# dtype: int64
